# %% [markdown]
# <h1><center><b> MBA em Ciência de Dados </b></center></h1>
# <h3><center> CeMEAI - ICMC/USP - São Carlos</center></h3>
#
# <br><br>
# <h2><center><b> Monitoria 21/07 </b></center></h2>
# <h3><center> Aprendizado de Máquina </center></h3>
#
# <br><br>
# <h4> Bruno Gomes Coelho</h4>
# <br><br>

# %% [markdown]
# # Dúvidas gerais

# %% [markdown]
# # Dúvidas comuns na avaliação
#
# - Inteligência Computacional
#     - Histórico, motivação humana e AI Winter

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# # Comentários e extras sobre o material

# %% [markdown]
# - Qual a relação entre Inteligência Artificial e Aprendizado de Máquina:
# - Qual o fato mais marcante do Dartmouth Summer Research Project?
# - O que podemos afirmar sobre Inteligência Artificial e Inteligência Computacional
# - Dean Pormeleau é famoso por ter
# - Assinalar a alternativa correta. Não é uma das subáreas da Inteligência Artificial

# %% [markdown]
# ## IA vs ML
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Teste de Turing
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Responsible DS
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - Trabalhos da Julia Stoyanovich - [site](http://stoyanovich.org/), [Responsible AI](https://airesponsibly.com/our-team/)
# - Interpretabilidade, Fairness, etc, são conceitos amplos: Responsabilidade

# %% [markdown]
# - Timnit Gebru

# %% [markdown]
# # ML
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Tarefas de aprendizado
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Dúvidas/Comentários?

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# # TACTD - Avaliação

# %% [markdown]
# Erros gerais:
# - Não rodar o notebook do início ao fim - Código faltando/não era possível rodar
# - .zip

# %% [markdown]
# ### Questão 1 (2.5 pontos)
# Considere o arquivo <font style="font-family: monaco"> modcovid.pdf </font> (disponível para download no moodle). Escreva um código para extrair o texto (ASCII) do arquivo PDF e escreva o texto extraído em um arquivo chamado ``modcovid.txt``.

# %% [markdown]
# - Consideramos a lógica e não a resposta necessariamente;
# - Código necessitar de pastas não criadas no código;
# - Não salvar o texto atraído

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ### Questão 2 (2.5 pontos)
# Leia o arquivo ``modcovid.txt`` e realize as seguinte operações:
# 1. Extraia todas palavras contidas no arquivo e armazene em uma lista de palavras (utilize o método <font color='blue'>word_tokenize</font> do pacote <font color='blue'>nltk</font>.
# 2. Remova da lista de palavras todos os "palavras" que não sejam formadas exclusivamente de caracteres do alfabeto.
# 3. Quantas palavras com apenas 1 caractere sobraram na lista?

# %%
# erros de processar
words = ["hello", "world", "bruno", "é"]

# %%
[w for w in words if w in string.ascii_letters]
# Out:
# []

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# #### 3.a (1.5 pontos)
#
# Exiba um histograma contendo a frequência dos diferentes gêneros dos artistas. Note que um artista pode ter mais do que um gênero associado.
#
# Dica: use a função `str.split(',')` para separar múltiplos gênero.

# %% [markdown]
# Maioria acertou

# %% [markdown]
# #### 3.b (1.0 ponto)
#
# Trate a coluna "paintings", a qual deveria conter apenas atributos numéricos inteiros. Siga os seguintes passos:
# 1. Exiba os valores não convertíveis para númerico
# 2. Convertendo-a para o tipo inteiro de forma que não haja perda de dados
#
# Após o tratamento exiba a estatística descritiva da coluna usando `describe()`
#
# Dica: usar expressões regulares pode ser útil nesse caso. Por exemplo a expressão `'(\d+)'` extrai apenas dígitos

# %% [markdown]
# 5 linhas a serem tratadas:
# -   70)
# - "117"
# -  '84'
# - three
# -  '25'

# %% [markdown]
# Erro comum: não chamar a função no final:
#
# ```python
# df.describe # correto deveria ser df.describe()
# ```

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ### Questão 4 (2.5 pontos)
#
# Dada uma imagem `query.jpg` de uma pintura da qual não sabemos o artista, gostaríamos de fazer uma busca numa base de dados e recuperar obras similares de acordo com suas cores. Para isso utilizaremos um descritor baseado em cores conhecido por **Border-Interior Classification (BIC)**, que funciona da seguinte forma:
#
# ...

# %% [markdown]
# - Errar índice de query
# - Não mostrar as 5 imagens

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# # Extra: Codificação e produtização

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ## Usando notebooks
# - [Problemas](https://www.youtube.com/watch?v=7jiPeIFXb6U) ...
#     - Difícil versionamento
#     - Código fora de ordem
# - ... e [benefícios](https://www.youtube.com/watch?v=9Q6sLbz37gk) de usar notebooks
#     - Media (markdown, imagens, etc) com código
#     - prototipização rapida
#     - Literate programming - [nbdev: use Jupyter Notebooks for everything](https://www.fast.ai/2019/12/02/nbdev/)
#
# ## Boas práticas de programação
# - Rodar  do  zero
# - Rodar em outra máquina
# - Versionamento: Git

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ## Data Science possui outras demandas
# - Versionamento de base de dados, artifatos e modelos
#     - Data Version Control - [DVC](https://dvc.org/): Substitui grande arquivos por meta-arquivos que são versionados com Git
#         - Re-uso do conhecimento de soft eng.
#         - Criação de pipelines
# - Monitoramento de experimentos, uso de GPU, etc - [Weights & Biases](https://wandb.ai/site)
#
# ## DevOps -> MLOps
# - Continuous Machine Learning (CML) - Monitoramento, reports automáticos e Pull Request para colocar modelos em produção, etc. [info](https://dvc.org/blog/cml-release), [link](https://cml.dev/)
#     - [Exemplo](https://blog.codecentric.de/en/2020/01/remote-training-gitlab-ci-dvc/) com GitLab CI
# -  [MLFlow](https://mlflow.org/)
# - Usar review/diffs de código em notebooks - [Reviewnb](https://www.reviewnb.com/)
#     - River - https://riverml.xyz/latest/
# - TPOT (automl), pajé (automl), PipelineProfiler (comparação de autoML), TSFresh (series temporais), Feauturetools (feat eng), auto-sklearn
# - AutoML, [H20](https://www.h2o.ai/products/h2o-automl/), rapido deploy
# - Airbnb's [Knowledge repo](https://github.com/airbnb/knowledge-repo) - Compartilhar e documentar o conhecimento da empresa

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# # Fin
